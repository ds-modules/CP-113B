# %%
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
# Don't worry about the content of this function for this lecture!
# Just note -- it generates a scatter plot with correlation approximately r

def r_scatter(r):
    plots.figure(figsize=(5,5))
    "Generate a scatter plot with a correlation approximately r"
    x = np.random.normal(0, 1, 1000)
    z = np.random.normal(0, 1, 1000)
    y = r*x + (np.sqrt(1-r**2))*z
    plots.scatter(x, y, s=20)
    plots.xlim(-4, 4)
    plots.ylim(-4, 4)

# %%
galton = Table.read_table('galton.csv')

# %%
heights = Table().with_columns(
    'MidParent', galton.column('midparentHeight'),
    'Child', galton.column('childHeight')
    )

# %%
heights
# Out:
# MidParent | Child
# 75.43     | 73.2
# 75.43     | 69.2
# 75.43     | 69
# 75.43     | 69
# 73.66     | 73.5
# 73.66     | 72.5
# 73.66     | 65.5
# 73.66     | 65.5
# 72.06     | 71
# 72.06     | 68
# ... (924 rows omitted)

# %%
heights.scatter('MidParent')

# %%
def predict_child(h):
    """Return a prediction of the height of a child 
    whose parents have a midparent height of h.
    
    The prediction is the average height of the children 
    whose midparent height is in the range h plus or minus 0.25 inches.
    """
    
    close_points = heights.where('MidParent', are.between(h-0.5, h + 0.5))
    return close_points.column('Child').mean()

# %%
heights_with_predictions = heights.with_column(
    'Prediction', heights.apply(predict_child, 'MidParent')
    )

# %%
heights_with_predictions.scatter('MidParent')

# %%
hybrid = Table.read_table('hybrid.csv')

# %%
hybrid.sort('msrp', descending=True)
# Out:
# vehicle         | year | msrp    | acceleration | mpg   | class
# Lexus LS600h/hL | 2007 | 118544  | 17.54        | 21    | Midsize
# ActiveHybrid 7  | 2010 | 104300  | 20.41        | 22.11 | Large
# ActiveHybrid 7i | 2011 | 102606  | 18.18        | 20    | Midsize
# ActiveHybrid X6 | 2009 | 97237.9 | 17.96        | 18.82 | SUV
# S400 Long       | 2009 | 96208.9 | 13.89        | 26.34 | Large
# Panamera S      | 2013 | 96150   | 18.52        | 25    | Large
# Panamera S      | 2012 | 95283.9 | 17.54        | 25    | Large
# S400            | 2013 | 92350   | 13.89        | 21    | Large
# S400            | 2010 | 88212.8 | 12.99        | 21    | Large
# ActiveHybrid 7L | 2013 | 84300   | 18.18        | 25    | Large
# ... (143 rows omitted)

# %%
hybrid.scatter('mpg', 'msrp')

# %%
hybrid.scatter('acceleration', 'msrp')

# %%
suv = hybrid.where('class', 'SUV')
suv.num_rows
# Out:
# 39

# %%
suv.scatter('acceleration', 'msrp')

# %%
suv.scatter('mpg', 'msrp')          ##the subset has a linear association, but when we looked at all hybrid cars, there was no linear relation

# %%
def standard_units(x):
    "Convert any array of numbers to standard units."
    return (x - np.average(x))/np.std(x)

# %%
Table().with_columns(
    'mpg (standard units)',  standard_units(suv.column('mpg')), 
    'msrp (standard units)', standard_units(suv.column('msrp'))
).scatter(0, 1)
plots.xlim(-3, 3)
plots.ylim(-3, 3);

# %%
Table().with_columns(
    'acceleration (standard units)', standard_units(suv.column('acceleration')), 
    'msrp (standard units)',         standard_units(suv.column('msrp'))
).scatter(0, 1)
plots.xlim(-3, 3)
plots.ylim(-3, 3);

# %%
r_scatter(0)         ##can change this

# %%
x = np.arange(1, 7, 1)
y = make_array(2, 3, 1, 5, 2, 7)
t = Table().with_columns(
        'x', x,
        'y', y
    )
t
# Out:
# x    | y
# 1    | 2
# 2    | 3
# 3    | 1
# 4    | 5
# 5    | 2
# 6    | 7

# %%
t.scatter(0, 1, s=30, color='red')

# %%
t_su = t.with_columns(
        'x (standard units)', standard_units(x),
        'y (standard units)', standard_units(y)
    )
t_su
# Out:
# x    | y    | x (standard units) | y (standard units)
# 1    | 2    | -1.46385           | -0.648886
# 2    | 3    | -0.87831           | -0.162221
# 3    | 1    | -0.29277           | -1.13555
# 4    | 5    | 0.29277            | 0.811107
# 5    | 2    | 0.87831            | -0.648886
# 6    | 7    | 1.46385            | 1.78444

# %%
t_product = t_su.with_column('product of standard units', t_su.column(2) * t_su.column(3))
t_product
# Out:
# x    | y    | x (standard units) | y (standard units) | product of standard units
# 1    | 2    | -1.46385           | -0.648886          | 0.949871
# 2    | 3    | -0.87831           | -0.162221          | 0.142481
# 3    | 1    | -0.29277           | -1.13555           | 0.332455
# 4    | 5    | 0.29277            | 0.811107           | 0.237468
# 5    | 2    | 0.87831            | -0.648886          | -0.569923
# 6    | 7    | 1.46385            | 1.78444            | 2.61215

# %%
# r is the average of the products of standard units

r = np.mean(t_product.column(4))



r
# Out:
# 0.6174163971897709

# %%
def correlation(t, label_x, label_y):
    '''t is a table; label_x and label_y are column labels'''
    x_in_standard_units = standard_units(t.column(label_x))
    y_in_standard_units = standard_units(t.column(label_y))
    return np.average(x_in_standard_units * y_in_standard_units)

# %%
correlation(suv, 'mpg', 'msrp')
# Out:
# -0.6667143635709919

# %%
correlation(suv, 'acceleration', 'msrp')
# Out:
# 0.48699799279959155

# %%
correlation(t, 'x', 'y')
# Out:
# 0.6174163971897709

# %%
correlation(t, 'y', 'x')
# Out:
# 0.6174163971897709

# %%
t.scatter('x', 'y')

# %%
t.scatter('y', 'x')

# %%
new_x = np.arange(-4, 4.1, 0.5)
nonlinear = Table().with_columns(
        'x', new_x,
        'y', new_x**2
    )
nonlinear.scatter('x', 'y', s=30, color='red')

# %%
correlation(nonlinear, 'x', 'y')    ##r only works for a linear association; since this is non-linear, we get linear correlation of 0.
# Out:
# 0.0

# %%
line = Table().with_columns(
        'x', make_array(1, 2, 3, 4),
        'y', make_array(1, 2, 3, 4)
    )
line.scatter('x', 'y', s=30, color='red')

# %%
correlation(line, 'x', 'y')
# Out:
# 1.0

# %%
outlier = Table().with_columns(
        'x', make_array(1, 2, 3, 4, 5),
        'y', make_array(1, 2, 3, 4, 0)
    )
outlier.scatter('x', 'y', s=30, color='red')

# %%
correlation(outlier, 'x', 'y')    #outlier makes the data have no linear correlation; do not compute the correlation coeff.
# Out:
# 0.0

# %%
sat2014 = Table.read_table('sat2014.csv').sort('State')
sat2014
# Out:
# State                | Participation Rate | Critical Reading | Math | Writing | Combined
# Alabama              | 6.7                | 547              | 538  | 532     | 1617
# Alaska               | 54.2               | 507              | 503  | 475     | 1485
# Arizona              | 36.4               | 522              | 525  | 500     | 1547
# Arkansas             | 4.2                | 573              | 571  | 554     | 1698
# California           | 60.3               | 498              | 510  | 496     | 1504
# Colorado             | 14.3               | 582              | 586  | 567     | 1735
# Connecticut          | 88.4               | 507              | 510  | 508     | 1525
# Delaware             | 100                | 456              | 459  | 444     | 1359
# District of Columbia | 100                | 440              | 438  | 431     | 1309
# Florida              | 72.2               | 491              | 485  | 472     | 1448
# ... (41 rows omitted)

# %%
sat2014.scatter('Critical Reading', 'Math')

# %%
correlation(sat2014, 'Critical Reading', 'Math')
# Out:
# 0.9847558411067434
