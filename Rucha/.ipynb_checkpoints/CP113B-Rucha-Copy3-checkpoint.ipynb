# %% [markdown]
# # CP-113B

# %% [markdown]
# ## Intro to Jupyter Notebook
#
# Jupyter Notebook is a user-friendly computing environment that allows users to interactively run and edit Python code.
#
# In this assignment, you will learn how to write basic code to take in quantitative data and turn it into qualitative analysis. MORE DESCRIPTION HERE
#
# First, let's learn a bit about Jupyter Notebook! For a full tutorial, you can check out the following link: https://jupyter-notebook.readthedocs.io/en/stable/
#
# Here, we just give you a brief introduction based off of the docs linked above.

# %% [markdown]
# #### Types of Cells
#
# 1. **Code cells**: cells that show input and output of live code
# 2. **Markdown cells**: cells in which you can write text such as decriptions of your code
# 3. **Raw cells**: unformatted text that is included when notebooks are converted to different format (you don't need to worry about these)
#
# #### How to Edit a Cell
# Double click on the cell to edit, and type in your changes! This applies to both code cells and markdown cells.
#
# #### How to Run a Cell
# Click on the icon in the tool bar that looks like a "play" button (it's located in between the down arrow and the square). INSERT IMAGE HERE? <br>
# Alternatively, you can hit *Ctrl+Enter* on a PC or *Command+Enter* on a Mac!
#
# #### How to Save Your Work
# Click on the leftmost  icon in the tool bar (left of the plus icon). <br>
# Alternatively, you can hit *Ctrl+S* on a PC or *Command+Enter* on a Mac!

# %%
# hi, hello

# %%
## These are all pre-written Python packages that we will be using to read in, clean, analyze, and model our data. 

# import utilities 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

## from widget notebook
#from datascience import *
import numpy as np
import math
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import ipywidgets as widgets
# %matplotlib inline

# %%
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\rucha\anaconda3\lib\site-packages (1.0.0)

# %%
# Read in data

df_2000 = pd.read_excel('CP113B Data for Redlining Analysis.xlsx')
# df_2017 = pd.read_excel('CP113B_Data_Redlining_Analysis_2017.xlsx') # might not need this after all

# %%
df_2000
# Out:
#            FIPS          Name of Area  Total Population  \
# 0    6001400100     Census Tract 4001              2463
# 1    6001400200     Census Tract 4002              1943
# 2    6001400300     Census Tract 4003              4879
# 3    6001400400     Census Tract 4004              3659
# 4    6001400500     Census Tract 4005              3415
# 5    6001400600     Census Tract 4006              1702
# 6    6001400700     Census Tract 4007              4451
# 7    6001400800     Census Tract 4008              3367
# 8    6001400900     Census Tract 4009              2457
# 9    6001401000     Census Tract 4010              5591
# 10   6001401100     Census Tract 4011              4007
# 11   6001401200     Census Tract 4012              2322
# 12   6001401300     Census Tract 4013              2920
# 13   6001401400     Census Tract 4014              4765
# 14   6001401500     Census Tract 4015              2578
# 15   6001401600     Census Tract 4016              1768
# 16   6001401700     Census Tract 4017              1768
# 17   6001401800     Census Tract 4018              2063
# 18   6001402200     Census Tract 4022              2463
# 19   6001402400     Census Tract 4024              2641
# 20   6001402500     Census Tract 4025              1695
# 21   6001402600     Census Tract 4026              1061
# 22   6001402700     Census Tract 4027              2006
# 23   6001402800     Census Tract 4028              1852
# 24   6001402900     Census Tract 4029              1276
# 25   6001403000     Census Tract 4030              2602
# 26   6001403100     Census Tract 4031              1676
# 27   6001403300     Census Tract 4033              2407
# 28   6001403400     Census Tract 4034              3625
# 29   6001403501  Census Tract 4035.01              4341
# ..          ...                   ...               ...
# 331  6001450742  Census Tract 4507.42              4427
# 332  6001450743  Census Tract 4507.43              4382
# 333  6001450744  Census Tract 4507.44              4944
# 334                    82634           1685               78.301213
# 335                    54778           1117               78.301213
# 336                     4990              6               83.425414
# 337                    47358             59               83.425414
# 338                    91998            115               83.425414
# 339                   133726           1611               85.474860
# 340                   167706            775               97.032258
# 341                   107410           2481               71.145688
# 342                   126020           1112               87.043379
# 343                   121230           2346               83.034953
# 344                   122542           2087               66.890273
# 345                    23170            734               58.668076
# 346                    66397           2104               58.668076
# 347                    86092           1288               54.425466
# 348                    97331           2057               67.428294
# 349                    23337            524               74.121058
# 350                    56562           1270               74.121058
# 351                    42983            965               74.121058
# 352                   111721           1402               64.265335
# 353                   105372           2327               62.440911
# 354                   101220           1054               82.447818
# 355                    45777           1145               79.948868
# 356                    63708           1593               79.948868
# 357                     4281             13               39.461883
# 358                    90398             11               36.363636
# 359                   154060             46               93.478261
# 360                        0              0                0.000000
#
#      Median House Value
# 0                985548
# 1                677115
# 2                566044
# 3                560128
# 4                343300
# 5                386837
# 6                265504
# 7                240381
# 8                199699
# 9                230378
# 10               370707
# 11               447788
# 12               463919
# 13               205552
# 14               240238
# 15               187423
# 16               194560
# 17               174719
# 18               359810
# 19               280949
# 20               244093
# 21               112911
# 22               252073
# 23               271199
# 24                    0
# 25               231959
# 26               310611
# 27               231388
# 28               287201
# 29               182304
# ..                  ...
# 331              555418
# 332              277033
# 333              312501
# 334              323447
# 335              214413
# 336               21797
# 337              206859
# 338              401845
# 339              566266
# 340              666473
# 341              342650
# 342              389627
# 343              404537
# 344              537146
# 345               87183
# 346              249836
# 347              400112
# 348              399969
# 349               94366
# 350              228718
# 351              173809
# 352              688027
# 353              493038
# 354              389549
# 355              207161
# 356              288304
# 357               11611
# 358              196273
# 359              342158
# 360                   0
#
# [361 rows x 15 columns]

# %%
import geojson
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-6fb141fad15c> in <module>()
# ----> 1 import geojson
#
# ModuleNotFoundError: No module named 'geojson'

# %%
# alameda coordinates from Soc130 resources

alameda = geojson.load(open("../Soc130 Resources/data/alameda-2010.geojson"))

# %%
# make 

df_alameda = pd.DataFrame(data=alameda)

# %%
import re

# %%
test = df_alameda['features'][0]

# %%
test

# %%
re.findall(r'(Census Tract \d*)', str(test))[0]

# %%
# extract census tracts from features in df_alameda

census_tracts = []
for feature in df_alameda['features']:
    census_tracts.append(re.findall(r'(Census Tract \d*)', str(feature))[0])

# %%
df_alameda['Name of Area'] = census_tracts

# %%
joined_df = pd.merge(df_2000, df_alameda, on='Name of Area')

# %%
joined_df.shape

# %%
dict_feat = dict(joined_df['features'][0])
dict_feat['geometry']['coordinates'][0][0][0]

# %%
dict_feat['geometry']['coordinates'][0][0][1]

# %%
# widget imports 
# import the widgets module
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

# %%
df_2000.columns.tolist()

# %%
def scatter_features(feature1, feature2):
    x = df_2000[[feature1]]
    y = df_2000[[feature2]]
    return plt.scatter(x,y)

# create drop down menus for widget
wid_1 = widgets.Dropdown(
    options=df_2000.columns.tolist(),
    description='Variable:',
    disabled=False,
)

wid_2 = widgets.Dropdown(
    options=df_2000.columns.tolist(),
    description='Variable:',
    disabled=False,
)

interact(scatter_features, feature1 = wid_1, feature2 = wid_2)

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('cartodb-query.shp')

# %%
# %matplotlib inline

gdf.plot(figsize=(10,10))

# %%
gdf

# %%
len(gdf)

# %%
# geo_df_joined = df_2000.set_index('Name of Area').join(gdf.set_index('name'))

# don't use - NaN values for all gdf columns

# %%
test_color = gdf['area_descr'][10]

# %%
test_color

# %%
re.findall(r'"(.*?)"', test_color)

# %%
town_color = re.findall(r'"(.*?)"', test_color)[1]
town_color

# %%
re.findall(r'California.*',town_color)[0][11:]

# %%
re.findall(r'.*California',town_color)[0]

# %%
colors = ['item_0']
towns = ['item_0']

for area in gdf['area_descr']:
    town_and_color = re.findall(r'"(.*?)"', area)[1]
    if len(re.findall(r'California',area))==0:
        if len(re.findall(r'Berkeley',area))>0:
            colors.append(re.findall(r'Berkeley.[^ACD]*',town_and_color)[0][9:])
            towns.append('Berkeley')
        if len(re.findall(r'Oakland',area))>0:
            colors.append(re.findall(r'Oakland.[^ACD]*',town_and_color)[0][8:])
            towns.append('Oakland')
        if len(re.findall(r'San Leandro',area))>0:
            colors.append(re.findall(r'San Leandro.[^ACD]*',town_and_color)[0][11:])
            towns.append('San Leandro')
            
    else: 
        colors.append(re.findall(r'California.[^ACD]*',town_and_color)[0][11:])
        towns.append(re.findall(r'.*California',town_and_color)[0].replace(', California',""))

# %%
colors

# %% [markdown]
# Consider making a list of the colors, and then only get the items from that list.

# %%
wanted_colors = ['item_0']    ##initialize list of wanted colors
for i in colors:
    if 'Low Green' in i:
        wanted_colors.append('Dark Green')
    elif 'High Green' in i:
        wanted_colors.append('Light Green')
    elif 'Green' in i:
        wanted_colors.append('Green')
    elif 'High Blue' in i:
        wanted_colors.append('Light Blue')
    elif 'Low Blue' in i:
        wanted_colors.append('Dark Blue')
    elif 'Blue' in i:
        wanted_colors.append('Blue')
    elif 'Low Yellow' in i:
        wanted_colors.append('Light Yellow')
    elif 'High Yellow' in i:
        wanted_colors.append('Dark Yellow')
    elif 'Yellow' in i:
        wanted_colors.append('Yellow')
    else:
        wanted_colors.append('Red')

wanted_colors

# %%
del wanted_colors[1]  ##delete the extra 'Red' in the 1st position because it was due to the else case above

# %%
len(wanted_colors) == len(colors)

# %%
towns

# %%
gdf['colors'],gdf['towns'] = wanted_colors,towns

# %%
gdf
# Out:
#      name holc_id holc_grade  \
# 0    None       A          A
# 1    None      A1          A
# 2    None     A10          A
# 3    None     A11          A
# 4    None      A2          A
# 5    None      A3          A
# 6    None      A4          A
# 7    None      A5          A
# 8    None      A6          A
# 9    None      A7          A
# 10   None      A8          A
# 11   None      A9          A
# 12   None      B1          B
# 13   None     B10          B
# 14   None     B11          B
# 15   None     B12          B
# 16   None     B13          B
# 17   None     B14          B
# 18   None     B15          B
# 19   None     B16          B
# 20   None     B17          B
# 21   None     B18          B
# 22   None     B19          B
# 23   None      B2          B
# 24   None     B20          B
# 25   None     B21          B
# 26   None     B22          B
# 27   None     B23          B
# 28   None     B24          B
# 29   None     B25          B
# ..    ...     ...        ...
# 89   None     C38          C
# 90   None     C39          C
# 91   None      C4          C
# 92   None     C40          C
# 93   None     C41          C
# 94   None      C5          C
# 95   None      C6          C
# 96   None      C7          C
# 97   None      C8          C
# 98   None      C9          C
# 99   None      D1          D
# 100  None     D10          D
# 101  None     D11          D
# 102  None     D12          D
# 103  None     D13          D
# 104  None     D14          D
# 105  None     D15          D
# 106  None     D16          D
# 107  None     D17          D
# 108  None     D18          D
# 109  None     D19          D
# 110  None      D2          D
# 111  None     D20          D
# 112  None      D3          D
# 113  None      D4          D
# 114  None      D5          D
# 115  None      D6          D
# 116  None      D7          D
# 117  None      D8          D
# 118  None      D9          D
#
#                                             area_descr  \
# 0                                          { "" : "" }
# 1    { "1" : "Berkeley Green A-1", "10a" : "fair", ...
# 2    { "1" : "Oakland, California Low Green A-10", ...
# 3    { "1" : "Oakland, California Green A-11", "10a...
# 4    { "1" : "Berkeley, California Green A-2", "10a...
# 5    { "1" : "Berkeley, California Low Green A-3", ...
# 6    { "1" : "Berkeley, California High Green A-4",...
# 7    { "1" : "Oakland High Green A-5", "10a" : "poo...
# 8    { "1" : "Oakland, California Green A-6", "10a"...
# 9    { "1" : "Piedmont, California High Green A-7",...
# 10   { "1" : "Piedmont, California High Green A-8",...
# 11   { "1" : "Oakland, California High Green A-9", ...
# 12   { "1" : "Berkeley, California Blue B-1", "10a"...
# 13   { "1" : "Oakland, California High Blue B-10", ...
# 14   { "1" : "Oakland, California High Blue B-11", ...
# 15   { "1" : "Oakland, California High Blue B-12", ...
# 16   { "1" : "Oakland, California Blue B-13", "10a"...
# 17   { "1" : "Piedmont, California Low Blue B-14", ...
# 18   { "1" : "Piedmont, California High Blue B-15",...
# 19   { "1" : "Oakland, California Blue B-16", "10a"...
# 20   { "1" : "Oakland, California Low Blue B-17", "...
# 21   { "1" : "Oakland, California Low Blue B-18", "...
# 22   { "1" : "Oakland, California High Blue B-19", ...
# 23   { "1" : "Albany, California Blue B-2", "10a" :...
# 24   { "1" : "Oakland, California Blue B-20", "10a"...
# 25   { "1" : "Oakland, California High Blue B-21", ...
# 26   { "1" : "Oakland, California High Blue B-22", ...
# 27   { "1" : "Oakand, California Low Blue B-23", "1...
# 28   { "1" : "Oakland, California High Blue B-24", ...
# 29   { "1" : "Oakland, California Low Blue B-25", "...
# ..                                                 ...
# 89   { "1" : "Alameda, California Low Yellow C-38",...
# 90   { "1" : "Alameda, California Yellow C-39", "10...
# 91   { "1" : "Berkeley, California Yellow C-4", "10...
# 92   { "1" : "Alameda, California High Yellow C-40"...
# 93   { "1" : "Alameda, California Low Yellow C-41",...
# 94   { "1" : "Berkeley, California High Yellow C-5"...
# 95   { "1" : "Berkeley, California Yellow C-6", "10...
# 96   { "1" : "Berkeley, California Low Yellow C-7",...
# 97   { "1" : "Emeryville, California High Yellow C-...
# 98   { "1" : "Oakland, California Yellow C-9", "10a...
# 99   { "1" : "Berkeley, California Red (slide) D-1"...
# 100  { "1" : "Oakland, California Red D-10", "10a" ...
# 101  { "1" : "Oakland, California Red D-11", "10a" ...
# 102  { "1" : "Oakland, California Red (slide) D-12"...
# 103  { "1" : "Oakland, California Red (slide) D-13"...
# 104  { "1" : "Oakland, California Red D-14", "10a" ...
# 105  { "1" : "Oakland, California Red D-15", "10a" ...
# 106  { "1" : "Oakland, California Red D-16", "10a" ...
# 107  { "1" : "Oakland, California Red (slide) D-17"...
# 108  { "1" : "Oakland, California Red D-18", "10a" ...
# 109  { "1" : "San Leandro, California Red D-19", "1...
# 110  { "1" : "Berkeley, California Red D-2", "10a" ...
# 111  { "1" : "Alameda, California Red D-20", "10a" ...
# 112  { "1" : "Berkeley, California Red D-3", "10a" ...
# 113  { "1" : "Berkeley, California Red D-4", "10a" ...
# 114  { "1" : "Oakland, California Red D-5", "10a" :...
# 115  { "1" : "Emeryville, California Red D-6", "10a...
# 116  { "1" : "Oakland, California Red D-7", "10a" :...
# 117  { "1" : "Oakland, California Red D-8", "10a" :...
# 118  { "1" : "Oakland, California Red D-9", "10a" :...
#
#                                               geometry          colors  \
# 0    POLYGON ((-122.2025219245971 37.81098621368113...          item_0
# 1    POLYGON ((-122.263194014919 37.9003948457167, ...          Green
# 2    POLYGON ((-122.2340298202495 37.80670967378922...      Low Green
# 3    POLYGON ((-122.2025219245971 37.81098621368113...          Green
# 4    POLYGON ((-122.2784713548339 37.89710197965462...          Green
# 5    POLYGON ((-122.2631116986962 37.88555152865671...      Low Green
# 6    POLYGON ((-122.24212858888 37.85181706358391, ...     High Green
# 7    POLYGON ((-122.2381026470004 37.84148609800512...     High Green
# 8    POLYGON ((-122.2156043595743 37.83192637951929...          Green
# 9    POLYGON ((-122.2246064794444 37.8304715147809,...     High Green
# 10   POLYGON ((-122.2104642902484 37.81875755212257...     High Green
# 11   POLYGON ((-122.2315358418993 37.816451877856, ...     High Green
# 12   POLYGON ((-122.2871625336482 37.89146007538827...        Blue B-1
# 13   POLYGON ((-122.2646159285378 37.84359992847578...  High Blue B-10
# 14   POLYGON ((-122.2397426374343 37.84910625540677...  High Blue B-11
# 15   POLYGON ((-122.2345691417967 37.84934241786874...  High Blue B-12
# 16   POLYGON ((-122.2247767371402 37.841797363526, ...       Blue B-13
# 17   POLYGON ((-122.2246064794444 37.8304715147809,...   Low Blue B-14
# 18   POLYGON ((-122.2315358418993 37.816451877856, ...  High Blue B-15
# 19   POLYGON ((-122.2478784355191 37.82527058568157...       Blue B-16
# 20   POLYGON ((-122.252755017294 37.82203719482894,...   Low Blue B-17
# 21   POLYGON ((-122.2484008031619 37.81351459640231...   Low Blue B-18
# 22   POLYGON ((-122.2321210493911 37.81658001005614...  High Blue B-19
# 23   POLYGON ((-122.2897484896021 37.89764215753791...        Blue B-2
# 24   POLYGON ((-122.2438742490391 37.8078826048926,...       Blue B-20
# 25   POLYGON ((-122.2172833234167 37.81309900257263...  High Blue B-21
# 26   POLYGON ((-122.2085352210578 37.81072332725354...  High Blue B-22
# 27   POLYGON ((-122.2134627543774 37.81070787412946...   Low Blue B-23
# 28   POLYGON ((-122.221051472166 37.79809768783331,...  High Blue B-24
# 29   POLYGON ((-122.2189213420485 37.79450699167011...   Low Blue B-25
# ..                                                 ...             ...
# 89   POLYGON ((-122.2399521416265 37.76626150278344...     Low Yellow
# 90   POLYGON ((-122.2591438176284 37.76435751670193...         Yellow
# 91   POLYGON ((-122.2732024733845 37.87250609153186...         Yellow
# 92   POLYGON ((-122.225201256689 37.76423242923272,...    High Yellow
# 93   POLYGON ((-122.2292893476132 37.75444246607262...     Low Yellow
# 94   POLYGON ((-122.2506226189305 37.8808961193936,...    High Yellow
# 95   (POLYGON ((-122.2592118003325 37.8650285236867...         Yellow
# 96   (POLYGON ((-122.2679909026535 37.8597783799284...     Low Yellow
# 97   POLYGON ((-122.276836743512 37.83727756015656,...    High Yellow
# 98   (POLYGON ((-122.2615376203498 37.8440325453397...         Yellow
# 99   POLYGON ((-122.2659077625103 37.8900099399906,...    Red (slide)
# 100  POLYGON ((-122.2321416872865 37.78507686189916...            Red
# 101  POLYGON ((-122.2695112868988 37.80022403155059...            Red
# 102  POLYGON ((-122.2201601736226 37.79480157279403...    Red (slide)
# 103  POLYGON ((-122.2147588616356 37.78365422852327...    Red (slide)
# 104  POLYGON ((-122.2135262814377 37.77566375052237...            Red
# 105  POLYGON ((-122.2410731977786 37.77951251671762...            Red
# 106  POLYGON ((-122.1710626161234 37.78068326547408...            Red
# 107  POLYGON ((-122.173675177481 37.77347004568867,...    Red (slide)
# 108  (POLYGON ((-122.1762263102429 37.7514162957680...            Red
# 109  POLYGON ((-122.157717681742 37.72632856096061,...            Red
# 110  (POLYGON ((-122.2739242077315 37.8702540120221...            Red
# 111  POLYGON ((-122.2315919839096 37.76933482879663...            Red
# 112  (POLYGON ((-122.2891131165915 37.8497415795475...            Red
# 113  (POLYGON ((-122.2727595769999 37.8595937924594...            Red
# 114  POLYGON ((-122.2607390171639 37.84620223124089...            Red
# 115  POLYGON ((-122.2826191657582 37.83666194870627...            Red
# 116  (POLYGON ((-122.2734177205063 37.8152672733994...            Red
# 117  POLYGON ((-122.2795750411616 37.82746529706706...            Red
# 118  POLYGON ((-122.2740293393658 37.81050786254944...            Red
#
#            towns
# 0         item_0
# 1       Berkeley
# 2        Oakland
# 3        Oakland
# 4       Berkeley
# 5       Berkeley
# 6       Berkeley
# 7        Oakland
# 8        Oakland
# 9       Piedmont
# 10      Piedmont
# 11       Oakland
# 12      Berkeley
# 13       Oakland
# 14       Oakland
# 15       Oakland
# 16       Oakland
# 17      Piedmont
# 18      Piedmont
# 19       Oakland
# 20       Oakland
# 21       Oakland
# 22       Oakland
# 23        Albany
# 24       Oakland
# 25       Oakland
# 26       Oakland
# 27        Oakand
# 28       Oakland
# 29       Oakland
# ..           ...
# 89       Alameda
# 90       Alameda
# 91      Berkeley
# 92       Alameda
# 93       Alameda
# 94      Berkeley
# 95      Berkeley
# 96      Berkeley
# 97    Emeryville
# 98       Oakland
# 99      Berkeley
# 100      Oakland
# 101      Oakland
# 102      Oakland
# 103      Oakland
# 104      Oakland
# 105      Oakland
# 106      Oakland
# 107      Oakland
# 108      Oakland
# 109  San Leandro
# 110     Berkeley
# 111      Alameda
# 112     Berkeley
# 113     Berkeley
# 114      Oakland
# 115   Emeryville
# 116      Oakland
# 117      Oakland
# 118      Oakland
#
# [119 rows x 7 columns]
